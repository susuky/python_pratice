# %%
import gym
import numpy as np
import time

from fastprogress.fastprogress import master_bar, progress_bar

# %%
env = gym.make('FrozenLake8x8-v0')

# %%
seed = 0
env.seed(seed)
np.random.seed(seed)

# %%
state_dim = env.observation_space.n
action_dim = env.action_space.n
state_dim, action_dim
# Out:
# (64, 4)

# %%
env.reset()
env.render()
# Out:
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG

# %%
dna_size = 64
pop_size = 1500
mutation_rate = 0.4
cross_rate = 0.5
generations = 300

# %%
def evaluate_policy(env, policy, times=100):
    total_rewards = 0.0
    for _ in range(times):
        obs = env.reset()
        while True:
            action = policy[obs]
            obs, reward, done, _ = env.step(action)
            total_rewards += reward
            if done:
                break
    return total_rewards / times

# %%
def select(pop, ranks):
    return [pop[x] for x in ranks[:keeps]]


def crossover(policy1, policy2):
    new_policy = policy1.copy()
    rand = np.random.uniform(size=dna_size) < cross_rate
    new_policy[rand] = policy2[rand]
    return new_policy


def mutation(policy):
    new_policy = policy.copy()
    rand = np.random.uniform(size=dna_size) < mutation_rate
    new_policy[rand] = np.random.choice(4)
    return new_policy

# %%
keeps = 25

best_score = 0.0
policy_pop = np.random.choice(4, size=(pop_size, dna_size))

# %%
mb = master_bar(range(generations))
mb.write(('generation', 'score', 'time'), table=True)
for generation in mb:
    progress_bar(np.array([0]), total=1, parent=mb)
    start_time = time.time()

    # step decay mutation rate
    if generation % 10 == 0:
        if mutation_rate > 0.001:
            mutation_rate /= 2
            mutation_rate = max(mutation_rate, 0.005)

    # get_fitness
    trn_tqdm = progress_bar(policy_pop, total=int(len(policy_pop)), parent=mb)
    policy_scores = [evaluate_policy(env, policy) for policy in trn_tqdm]
    policy_ranks = np.argsort(policy_scores)[::-1]
    score = np.mean(np.array(policy_scores)[policy_ranks[:50]])

    # checkpoint
    if score > best_score:
        print(
            f'generation: {generation+1}, '
            f'improve score from {best_score:.4f} to {score:.4f}, '
            'save as checkpoint3.npy'
        )
        np.save(f'checkpoint3', policy_pop)
        best_score = score

    # keeps
    elite_set = select(policy_pop, policy_ranks)

    # select
    select_probs = np.array(policy_scores) / np.sum(policy_scores)

    # crossover
    child_set = [
        crossover(policy_pop[np.random.choice(pop_size, p=select_probs)],
                  policy_pop[np.random.choice(pop_size, p=select_probs)])
        for _ in range(pop_size - keeps)
    ]
    keeps += 1

    # mutation
    mutated_list = [mutation(c) for c in child_set]

    # sum
    policy_pop = np.array(elite_set + mutated_list)

    # calculate time
    end_time = time.time()
    m, s = divmod(end_time - start_time, 60)

    # print
    mb.write((f'{generation+1}', f'{score:.4f}', f'{m:.0f}:{s:.0f}'),
             table=True)
env.close()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>generation</th>
#       <th>score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.0436</td>
#       <td>0:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.1676</td>
#       <td>0:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.3256</td>
#       <td>0:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.4570</td>
#       <td>0:48</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.5580</td>
#       <td>0:52</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.6220</td>
#       <td>0:52</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.6636</td>
#       <td>0:54</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.7088</td>
#       <td>0:54</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.7380</td>
#       <td>0:55</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.7666</td>
#       <td>0:57</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.7774</td>
#       <td>0:58</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.7978</td>
#       <td>1:1</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.8138</td>
#       <td>1:5</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.8262</td>
#       <td>1:7</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.8332</td>
#       <td>1:9</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0
td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.9438</td>
#       <td>1:46</td>
#     </tr>
#     <tr>
# generation: 1, improve score from 0.0000 to 0.0436, save as checkpoint3.npy
# generation: 2, improve score from 0.0436 to 0.1676, save as checkpoint3.npy
# generation: 3, improve score from 0.1676 to 0.3256, save as checkpoint3.npy
# generation: 4, improve score from 0.3256 to 0.4570, save as checkpoint3.npy
# generation: 5, improve score from 0.4570 to 0.5580, save as checkpoint3.npy
# generation: 6, improve score from 0.5580 to 0.6220, save as checkpoint3.npy
# generation: 7, improve score from 0.6220 to 0.6636, save as checkpoint3.npy
# generation: 8, improve score from 0.6636 to 0.7088, save as checkpoint3.npy
# generation: 9, improve score from 0.7088 to 0.7380, save as checkpoint3.npy
# generation: 10, improve score from 0.7380 to 0.7666, save as checkpoint3.npy
# generation: 11, improve score from 0.7666 to 0.7774, save as checkpoint3.npy
# generation: 12, improve score from 0.7774 to 0.7978, save as checkpoint3.npy
# generation: 13, improve score from 0.7978 to 0.8138, save as checkpoint3.npy
# generation: 14, improve score from 0.8138 to 0.8262, save as checkpoint3.npy
# generation: 15, improve score from 0.8262 to 0.8332, save as checkpoint3.npy
# generation: 16, improve score from 0.8332 to 0.8486, save as checkpoint3.npy
# generation: 17, improve score from 0.8486 to 0.8564, save as checkpoint3.npy
# generation: 18, improve score from 0.8564 to 0.8648, save as checkpoint3.npy
# generation: 19, improve score from 0.8648 to 0.8670, save as checkpoint3.npy
# generation: 20, improve score from 0.8670 to 0.8686, save as checkpoint3.npy
# generation: 21, improve score from 0.8686 to 0.8764, save as checkpoint3.npy
# generation: 22, improve score from 0.8764 to 0.8830, save as checkpoint3.npy
# generation: 23, improve score from 0.8830 to 0.8850, save as checkpoint3.npy
# generation: 24, improve score from 0.8850 to 0.8940, save as checkpoint3.npy
# generation: 25, improve score from 0.8940 to 0.9016, save as checkpoint3.npy
# generation: 28, improve score from 0.9016 to 0.9026, save as checkpoint3.npy
# generation: 29, improve score from 0.9026 to 0.9084, save as checkpoint3.npy
# generation: 30, improve score from 0.9084 to 0.9110, save as checkpoint3.npy
# generation: 33, improve score from 0.9110 to 0.9138, save as checkpoint3.npy
# generation: 34, improve score from 0.9138 to 0.9210, save as checkpoint3.npy
# generation: 36, improve score from 0.9210 to 0.9214, save as checkpoint3.npy
# generation: 38, improve score from 0.9214 to 0.9232, save as checkpoint3.npy
# generation: 39, improve score from 0.9232 to 0.9254, save as checkpoint3.npy
# generation: 41, improve score from 0.9254 to 0.9292, save as checkpoint3.npy
# generation: 45, improve score from 0.9292 to 0.9294, save as checkpoint3.npy
# generation: 47, improve score from 0.9294 to 0.9320, save as checkpoint3.npy
# generation: 48, improve score from 0.9320 to 0.9340, save as checkpoint3.npy
# generation: 51, improve score from 0.9340 to 0.9342, save as checkpoint3.npy
# generation: 53, improve score from 0.9342 to 0.9392, save as checkpoint3.npy
# generation: 59, improve score from 0.9392 to 0.9392, save as checkpoint3.npy
# generation: 63, improve score from 0.9392 to 0.9398, save as checkpoint3.npy
# generation: 64, improve score from 0.9398 to 0.9440, save as checkpoint3.npy
# generation: 72, improve score from 0.9440 to 0.9462, save as checkpoint3.npy
# generation: 76, improve score from 0.9462 to 0.9470, save as checkpoint3.npy
# generation: 97, improve score from 0.9470 to 0.9472, save as checkpoint3.npy
# generation: 100, improve score from 0.9472 to 0.9478, save as checkpoint3.npy
# generation: 110, improve score from 0.9478 to 0.9490, save as checkpoint3.npy
# generation: 136, improve score from 0.9490 to 0.9494, save as checkpoint3.npy
# generation: 149, improve score from 0.9494 to 0.9496, save as checkpoint3.npy
# generation: 184, improve score from 0.9496 to 0.9502, save as checkpoint3.npy
# generation: 206, improve score from 0.9502 to 0.9526, save as checkpoint3.npy

# %%
policy_pop = np.load('checkpoint3.npy')

# %%
policy_pop = np.unique(policy_pop, axis=0);policy_pop.shape
# Out:
# (1500, 64)

# %%
test_tqdm = progress_bar(policy_pop, total=int(len(policy_pop)))
policy_score = [evaluate_policy(env, pp, times=100) for pp in test_tqdm]
index = np.argmax(policy_score)
best_policy = policy_pop[index]
print(f'index: {index}')
print('Best actions score =', (np.max(policy_score)), '\n'
      'best actions =\n', best_policy)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1500' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1500/1500 01:42<00:00]
#     </div>
# index: 289
# Best actions score = 0.97
# best actions =
#  [3 2 2 1 2 2 2 2 3 3 3 3 3 3 3 2 3 3 2 1 2 3 2 2 0 1 2 0 0 0 2 2 2 2 3 2 3
#  2 3 2 3 0 1 2 2 2 3 2 1 0 1 2 3 1 1 2 2 1 3 2 1 0 2 1]

# %%
index = np.argsort(policy_score)[-200:][::-1]
for i in index[:10]:
    print(i, policy_score[i])
# Out:
# 1065 0.97
# 289 0.97
# 1253 0.97
# 687 0.97
# 63 0.96
# 489 0.96
# 853 0.96
# 484 0.96
# 891 0.95
# 333 0.95

# %%
# Testing: Calculating the average reward of 1000 eposides
test_episodes = 1000  # DON'T CHANGE THIS VALUE
tests = 100
best_score = 0.0

rewards_list = []

mb = master_bar(range(tests))
for test in mb:
    
    index_tqdm = progress_bar(index, total=int(len(index)), parent=mb)
    for idx in index_tqdm:        
        steps = 0
        total_reward = 0
        
        for i in range(test_episodes):
            
            state = env.reset()
            done = False
            while not done:
                action = policy_pop[idx][state]
                next_state, reward, done, _ = env.step(action)
                state = next_state
                steps = steps + 1
                total_reward = total_reward + reward

        total_avg_reward = total_reward / test_episodes
        total_avg_step = steps / test_episodes
        rewards_list.append(total_avg_reward)
        if total_avg_reward > best_score:
            print("The average results of {} episodes are steps: {}, reward: {}".format(
                test_episodes, total_avg_step, total_avg_reward))
            best_score = total_avg_reward
    
total_avg_reward = max(rewards_list)
total_avg_reward
# Out:
# The average results of 1000 episodes are steps: 110.418, reward: 0.897
# The average results of 1000 episodes are steps: 107.621, reward: 0.9
# The average results of 1000 episodes are steps: 108.164, reward: 0.905
# The average results of 1000 episodes are steps: 107.537, reward: 0.909
# The average results of 1000 episodes are steps: 107.197, reward: 0.91
# The average results of 1000 episodes are steps: 108.402, reward: 0.912
# The average results of 1000 episodes are steps: 106.493, reward: 0.913
# The average results of 1000 episodes are steps: 105.353, reward: 0.917
# The average results of 1000 episodes are steps: 106.63, reward: 0.921
# The average results of 1000 episodes are steps: 105.029, reward: 0.924
# 0.924

# %%
total_avg_reward = max(rewards_list)
total_avg_reward
# Out:
# 0.924

# %%
# Print results in CSV format and upload to Kaggle
with open('rewards.csv', 'w') as f:
    f.write('Id,Predicted\n')
    f.write('FrozenLake8x8_public,{}\n'.format(total_avg_reward))
    f.write('FrozenLake8x8_private,{}\n'.format(total_avg_reward))
